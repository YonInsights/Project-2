# %%
import pandas as pd

# %%
data=pd.read_csv(r'D:\Data Analyis\Python practice\Projects\Project-2\TWO_CENTURIES_OF_UM_RACES.csv')
# Out:
# C:\Users\Yonatan\AppData\Local\Temp\ipykernel_9016\4195930458.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv(r'D:\Data Analyis\Python practice\Projects\Project-2\TWO_CENTURIES_OF_UM_RACES.csv')

# %%
import seaborn as sns

# %%
data.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
data.shape
# Out:
# (7461195, 13)

# %%
data.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#step 1 show 50Mi or 50k
#50km
#50mi
data[data['Event distance/length']=='50Km']
# Out:
#          Year of event Event dates                         Event name  \
# 2215552           2019  17.08.2019                  Capes 50 Km (CAN)
# 2215553           2019  17.08.2019                  Capes 50 Km (CAN)
# 2215554           2019  17.08.2019                  Capes 50 Km (CAN)
# 2215555           2019  17.08.2019                  Capes 50 Km (CAN)
# 2215556           2019  17.08.2019                  Capes 50 Km (CAN)
# ...                ...         ...                                ...
# 2900719           2021  10.07.2021  Wickerstedter-Ultramarathon (GER)
# 2900720           2021  10.07.2021  Wickerstedter-Ultramarathon (GER)
# 2900721           2021  10.07.2021  Wickerstedter-Ultramarathon (GER)
# 2900722           2021  10.07.2021  Wickerstedter-Ultramarathon (GER)
# 2900723           2021  10.07.2021  Wickerstedter-Ultramarathon (GER)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
data[data['Event distance/length']=='50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#Combine the 50km and 50mi
data[data['Event distance/length'].isin (['50Km','50mi'])]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
data[ (data['Event distance/length'].isin (['50Km','50mi']) ) & (data['Year of event']==2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2757700           2020      08.10.2020
# 2757701           2020      08.10.2020
# 2757702           2020      08.10.2020
# 2757703           2020      08.10.2020
# 2757704           2020      08.10.2020
#
#                                                Event name  \
# 2538571           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538572           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538573           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538574           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538575           Taipei 48hr Ultra Marathon - 50mi (TPE)
# ...                                                   ...
# 2757700  Täby Extreme Challenge 50 miles - Thursday (SWE)
# ...

# %%
data[data["Event name"]=="Everglades 50 Mile Ultra Run (USA)"]
# Out:
#          Year of event Event dates                          Event name  \
# 51923             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51924             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51925             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51926             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51927             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# ...                ...         ...                                 ...
# 6417091           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417092           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417093           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417094           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417095           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
data[data["Event name"]=="Everglades 50 Mile Ultra Run (USA)"]["Event name"].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
data[data["Event name"].str.split('(').str.get(1).str.split(')').str.get(0)=='USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
data[ (data['Event distance/length'].isin (['50Km','50mi']) ) & (data['Year of event']==2020)&(data["Event name"].str.split('(').str.get(1).str.split(')').str.get(0)=='USA')]
# Out:
#          Year of event Event dates                       Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# ...                ...         ...                              ...
# 2757274           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
# 2757275           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
# 2757276           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
# 2757277           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
# 2757278           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
data2=data[ (data['Event distance/length'].isin (['50Km','50mi']) ) & (data['Year of event']==2020)&(data["Event name"].str.split('(').str.get(1).str.split(')').str.get(0)=='USA')]

# %%
data2.head(10)
# Out:
#          Year of event Event dates                       Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542139           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542140           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542141           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542142           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542143           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10           8:51:11 h
# ...

# %%
data2.shape
# Out:
# (5668, 13)

# %%
#remove USA from the event name 
data2['Event name'].str.split('(').str.get(0)
# Out:
# 2542134    Elephant Mountain 50 Mile
# 2542135    Elephant Mountain 50 Mile
# 2542136    Elephant Mountain 50 Mile
# 2542137    Elephant Mountain 50 Mile
# 2542138    Elephant Mountain 50 Mile
#                       ...
# 2757274    Old Cascadia 50 Mile Race
# 2757275    Old Cascadia 50 Mile Race
# 2757276    Old Cascadia 50 Mile Race
# 2757277    Old Cascadia 50 Mile Race
# 2757278    Old Cascadia 50 Mile Race
# Name: Event name, Length: 5668, dtype: object

# %%
data2[ 'Event name']=data2[ 'Event name' ] . str. split('(' ) .str.get(0)
# Out:
# C:\Users\Yonatan\AppData\Local\Temp\ipykernel_9016\2615561676.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2[ 'Event name']=data2[ 'Event name' ] . str. split('(' ) .str.get(0)

# %%
data2.head(10)
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542139           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542140           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542141           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542142           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542143           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10           8:51:11 h
# 2542135                  50mi                         10          11:37:15 h
# ...

# %%
#Remove Athlete performance
data2[ 'Athlete performance']=data2[ 'Athlete performance' ] . str. split(' ' ) .str.get(0)
# Out:
# C:\Users\Yonatan\AppData\Local\Temp\ipykernel_9016\414848068.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2[ 'Athlete performance']=data2[ 'Athlete performance' ] . str. split(' ' ) .str.get(0)

# %%
data2.head(10)
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542139           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542140           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542141           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542142           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542143           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10             8:51:11
# 2542135                  50mi                         10            11:37:15
# ...

# %%
#remove some columen Athlete club,Athlete country,Athlete year of birth,Athlete age category
data2=data2.drop(["Athlete club",'Athlete country','Athlete year of birth','Athlete age category'],axis=1)

# %%
data2.head(10)
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542139           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542140           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542141           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542142           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542143           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10             8:51:11
# 2542135                  50mi                         10            11:37:15
# ...

# %%
#Clean up null value 
data2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# dtype: int64

# %%
data2.shape
# Out:
# (5668, 9)

# %%
#chack for dups
data2[data2.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID]
# Index: []

# %%
#rest index
data2.reset_index(drop = True)
# Out:
#       Year of event Event dates                  Event name  \
# 0              2020  01.02.2020  Elephant Mountain 50 Mile
# 1              2020  01.02.2020  Elephant Mountain 50 Mile
# 2              2020  01.02.2020  Elephant Mountain 50 Mile
# 3              2020  01.02.2020  Elephant Mountain 50 Mile
# 4              2020  01.02.2020  Elephant Mountain 50 Mile
# ...             ...         ...                         ...
# 5663           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5664           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5665           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5666           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5667           2020  10.10.2020  Old Cascadia 50 Mile Race
#
#      Event distance/length  Event number of finishers Athlete performance  \
# 0                     50mi                         10             8:51:11
# 1                     50mi                         10            11:37:15
# ...

# %%
#fix types
data2.dtypes
# Out:
# Year of event                 int64
# Event dates                  object
# Event name                   object
# Event distance/length        object
# Event number of finishers     int64
# Athlete performance          object
# Athlete gender               object
# Athlete average speed        object
# Athlete ID                    int64
# dtype: object

# %%
data2[ 'Athlete average speed']= data2[ 'Athlete average speed'].astype (float)

# %%
data2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# dtype: object

# %%
data2.head(5)
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10             8:51:11
# 2542135                  50mi                         10            11:37:15
# 2542136                  50mi                         10            11:59:00
# 2542137                  50mi                         10            12:04:40
# 2542138                  50mi                         10            12:26:20
#
#         Athlete gender  Athlete average speed  Athlete ID
# 2542134              M                  9.089       86674
# ...

# %%
#rename
data2=data2.rename(columns={
"Year of event":"year",
'Event dates':"date",
'Event name':"name",
'Event distance/length':"length",
'Event number of finishers':'no_finsher',
'Athlete performance':"performance",
'Athlete gender':"gender",
'Athlete average speed':"avg_speed",
'Athlete ID':"ID"

})

# %%
data2.head(5)
# Out:
#          year        date                        name length  no_finsher  \
# 2542134  2020  01.02.2020  Elephant Mountain 50 Mile    50mi          10
# 2542135  2020  01.02.2020  Elephant Mountain 50 Mile    50mi          10
# 2542136  2020  01.02.2020  Elephant Mountain 50 Mile    50mi          10
# 2542137  2020  01.02.2020  Elephant Mountain 50 Mile    50mi          10
# 2542138  2020  01.02.2020  Elephant Mountain 50 Mile    50mi          10
#
#         performance gender  avg_speed      ID
# 2542134     8:51:11      M      9.089   86674
# 2542135    11:37:15      M      6.924   53268
# 2542136    11:59:00      M      6.715  778567
# 2542137    12:04:40      M      6.662  209242
# 2542138    12:26:20      M      6.469  810742

# %%
data3=data2[['ID','name','gender',"date",'year','length','no_finsher','performance','avg_speed']]

# %%
data3.head()
# Out:
#              ID                        name gender        date  year length  \
# 2542134   86674  Elephant Mountain 50 Mile       M  01.02.2020  2020   50mi
# 2542135   53268  Elephant Mountain 50 Mile       M  01.02.2020  2020   50mi
# 2542136  778567  Elephant Mountain 50 Mile       M  01.02.2020  2020   50mi
# 2542137  209242  Elephant Mountain 50 Mile       M  01.02.2020  2020   50mi
# 2542138  810742  Elephant Mountain 50 Mile       M  01.02.2020  2020   50mi
#
#          no_finsher performance  avg_speed
# 2542134          10     8:51:11      9.089
# 2542135          10    11:37:15      6.924
# 2542136          10    11:59:00      6.715
# 2542137          10    12:04:40      6.662
# 2542138          10    12:26:20      6.469

# %%
#find 2 races that ran in 2020- Sarasota / Everglades

# %%
data3 [data3 ['name' ] =='Everglades 50 Mile Ultra Run ']
# Out:
#              ID                           name gender        date  year  \
# 2591476  820757  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# 2591477   46432  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# 2591478  813617  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# 2591479  820758  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# 2591480  647115  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# 2591481  696063  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# 2591482  222509  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# 2591483  820759  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# 2591484  359359  Everglades 50 Mile Ultra Run       F  14.03.2020  2020
# 2591485  103020  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# 2591486  202097  Everglades 50 Mile Ultra Run       F  14.03.2020  2020
# 2591487  820760  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
# ...

# %%
data3 [data3 ['ID' ] == 222509 ]
# Out:
#              ID                           name gender        date  year  \
# 2591482  222509  Everglades 50 Mile Ultra Run       M  14.03.2020  2020
#
#         length  no_finsher performance  avg_speed
# 2591482   50mi          40     9:19:10      8.634

# %%
sns.histplot (data3['length'] )
# Out:
# <Axes: xlabel='length', ylabel='Count'>

# %%
sns.histplot (data3,x='length',hue='gender')
# Out:
# <Axes: xlabel='length', ylabel='Count'>

# %%
sns.displot(data3[data3['length']=='50mi']  [ 'avg_speed'])

# %%
sns.violinplot(data=data3, x='length' , y='avg_speed',hue ="gender" )
# Out:
# <Axes: xlabel='length', ylabel='avg_speed'>

# %%
sns.lmplot (data=data3 ,x= 'no_finsher',y='avg_speed')

# %%
data3 . groupby( [ 'length','no_finsher',	'performance','avg_speed'])['avg_speed'].mean()
# Out:
# length  no_finsher  performance  avg_speed
# 50mi    2           11:10:02     7.206        7.206
#                     13:59:07     5.754        5.754
#         3           11:40:44     6.890        6.890
#                     12:35:00     6.395        6.395
#                     14:00:00     5.748        5.748
#                                               ...
#         636         9:57:49      8.076        8.076
#                     9:58:01      8.073        8.073
#                     9:58:10      8.071        8.071
#                     9:58:39      8.065        8.065
#                     9:59:29      8.054        8.054
# Name: avg_speed, Length: 5429, dtype: float64

# %%
result = (data3.query("length == '50mi'")
                .groupby('date')['avg_speed']
                .agg(['mean', 'count'])
                .sort_values('mean', ascending=False)
                .query('count > 90')
                .head(50))

print(result)
# Out:
#                     mean  count
# date
# 11.10.2020      8.369277    101
# 11.01.2020      7.822631    203
# 25.01.2020      7.808500    156
# 21.11.2020      7.728070    789
# 07.03.2020      7.395912    114
# 12.09.2020      7.320544    136
# 10.10.2020      7.209348    207
# 31.10.2020      7.094683    126
# 14.11.2020      7.059036    193
# 07.11.2020      7.025135    156
# 14.03.2020      7.021492    530
# 08.02.2020      6.888854    343
# 22.08.2020      6.842213    141
# 19.12.2020      6.705804     97
# 29.08.2020      6.696667    111
# 05.12.2020      6.569299    201
# 20.-21.09.2020  6.213029    102
# 13.06.2020      6.021839    248
# 30.05.2020      5.908200    100
